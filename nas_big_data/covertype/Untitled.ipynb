# %%
from nas_big_data.covertype.load_data import load_data

# %%
(X_train, y_train), (X_valid, y_valid) = load_data(use_test=True)
# Out:
# !!! USING TEST DATA !!!
# X_train shape: (522910, 54)
# y_train shape: (522910, 7)
# X_valid shape: (58102, 54)
# y_valid shape: (58102, 7)

# %%
def convert_to_dataframe(X, y):
    import numpy as np 
    import pandas as pd
    data = np.concatenate([X, np.argmax(y, axis=1).reshape(-1, 1)], axis=1)
    df_train = pd.DataFrame(data=data_train, columns=[f"x{i}" for i in range(np.shape(data_train)[-1]-1)]+["label"])

# %%
# Out:
#                  x0            x1            x2            x3            x4  \
# count  5.229100e+05  5.229100e+05  5.229100e+05  5.229100e+05  5.229100e+05
# mean  -2.211737e-13  7.854384e-15 -5.473405e-12  7.732981e-13 -7.600953e-13
# std    1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00
# min   -3.928022e+00 -1.390502e+00 -1.882958e+00 -1.267217e+00 -3.642145e+00
# 25%   -5.361741e-01 -8.721869e-01 -6.812971e-01 -7.592052e-01 -6.763005e-01
# 50%    1.314844e-01 -2.555704e-01 -1.472254e-01 -2.417856e-01 -2.819975e-01
# 75%    7.277356e-01  9.329803e-01  5.203642e-01  5.390478e-01  3.866033e-01
# max    3.209140e+00  1.826627e+00  6.929224e+00  5.304013e+00  9.507004e+00
#
#                  x5            x6            x7            x8            x9  \
# count  5.229100e+05  5.229100e+05  5.229100e+05  5.229100e+05  5.229100e+05
# mean  -5.794475e-14  1.423251e-11  2.893273e-11 -1.784048e-12  1.031745e-13
# ...
